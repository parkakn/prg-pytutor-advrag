# %%
from rag_tools.document_parsing import documentparser
from rag_tools.markdown_element import MarkdownElementNodeParser_mod

# %%
import glob
import pickle
import itertools
import nest_asyncio
from dotenv import load_dotenv
import os

from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core.extractors import (SummaryExtractor,TitleExtractor)
from llama_index.core.schema import BaseNode, TextNode, Document
from llama_index.core.node_parser import LlamaParseJsonNodeParser

# %%
# Load environment variables from .env file
load_dotenv()

nest_asyncio.apply()

openai_api_key = os.getenv("OPENAI_API_KEY")
llama_cloud_api_key = os.getenv("LLAMA_CLOUD_API_KEY")

# %% [markdown]
# ### Parse documents

# %%
from document_parsing import documentparser

# %%
files = glob.glob("GSU - CIS 3260 - Fall 2023/Lecture Slides/*.pdf")

# %%
files[:2]
# Out:
# ['GSU - CIS 3260 - Fall 2023/Lecture Slides/Week 4.pdf',
#  'GSU - CIS 3260 - Fall 2023/Lecture Slides/Week 3.pdf']

# %%
md = documentparser.document_to_markdown(doc = files[:2],doc_type="lecture slide")
# Out:
# Started parsing the file under job_id fb64c4ef-9ec7-4bb2-b606-bcd59d77e33a
# Started parsing the file under job_id 4b824308-2ca0-4b1a-8a7f-befd4877af14

# %% [markdown]
# ### Load Parsed Document

# %%
import os

file_path = 'GSU - CIS 3260 - Fall 2023/Lecture Slides Parsed/Week 14.pkl'
base_path, _ = os.path.splitext(file_path)

# %%
base_path
# Out:
# 'GSU - CIS 3260 - Fall 2023/Lecture Slides Parsed/Week 14'

# %%
files = glob.glob("GSU - CIS 3260 - Fall 2023/Lecture Slides Parsed/*.pkl")  
loaded_files = []
for i in files:
    loaded_files.append(pickle.load(open(i, "rb")))

md = loaded_files[:2]

# %%
md
# Out:
# [[Document(id_='720eb6d8-4f68-4a81-a717-8c42d2eb139c', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Objectives for class 14\n\n- Review IA4-IA7\n- Review Quiz 3 – Quiz 5\n- Final Exam Schedule\n- Group Project Schedule\n---\n# Individual Assignment 4 - 2\n\n- Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.\n\n## Sample Run\n```\nEnter a letter grade: B\nThe numeric value for grade B is 80\n```\n\n```python\nletter = input("Enter a letter grade: ")\n\nif letter in \'Aa\':\n    print("The numeric value for grade A is 90")\nelif letter in \'Bb\':\n    print("The numeric value for grade B is 80")\nelif letter in \'Cc\':\n    print("The numeric value for grade C is 70")\nelif letter in \'Dd\':\n    print("The numeric value for grade D is 60")\nelse:\n    print(letter, "is an invalid grade")\n```\n\n- Letter in “Aa”\n- Multiple way if statements\n---\n# Individual Assignment 4 - 3\n\n- Display number of days in the month.\n\n## Sample Run\n```\nEnter a year: 2001\nEnter a month: Jan\nJan 2001 has 31 days\n```\n\nA year is a **leap** year if **either** of the following conditions is satisfied:\n- The year is multiple of 400.\n  - `(year % 400) == 0` (in python)\n- The year is multiple of 4 and not multiple of 100.\n  - `(year % 4) == 0 and (year % 100) != 0` (in python)\n\n```python\nyear = int(input("Enter a year: "))\nmonth = input("Enter a month (first three letters with the first letter in uppercase): ")\n\nif month == "Jan" or month == "Mar" or month == "May" \\\nor month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":\n    print(month, year, "has 31 days")\nelif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":\n    print(month, year, "has 30 days")\nelif month == "Feb":\n    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):\n        print(month, year, "has 29 days")\n    else:\n        print(month, year, "has 28 days")\nelse:\n    print(month, "is not a correct month name")\n```\n---\n# Individual Assignment 5 - 1\n\n- Prompts the user to enter a string and displays its length and its first character.\n\n## Sample Run\n\n```\nEnter a string: Programming is fun\nThe length of string "Programming is fun" is 18\nThe last character of string Programming is fun is n\n```\n\n## Code\n\n```python\ns = input("Enter a string: ")\n\nprint("The length of string \\"Programming is fun\\" is ", len(s))\n\nprint("The last character of string Programming is fun is ", s[-1])\n```\n---\n# Individual Assignment 5 - 2\n\n- **Decide major and year**\n  - M: Mathematics\n  - C: Computer Science\n  - I: Information Technology\n\n## Sample Run\n```\nEnter two characters: M1\nMathematics\nFreshman\n```\n\n```python\n# More efficient with list created\ns = input("Enter two characters: ")\n\nms = [\'M\', \'C\', \'I\']\nmajors = [\'Mathematics\', \'Computer Science\', \'Information Technology\']\nyears = [\'Freshman\', \'Sophomore\', \'Junior\', \'Senior\']\n\nyear = int(s[1])\nmajor = majors[ms.index(s[0])]\n\nprint(major)\nprint(years[year - 1])\n```\n---\n# Individual Assignment 5 - 3\n\n- **An ISBN-9 to ISBN-10 converter (without function)**\n\n  If the checksum is 10, the last digit is denoted as X according to the ISBN-10 convention.\n\n  ```\n  checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d₄ * 4 + d₅ * 5 + d₆ * 6 + d₇ * 7 + d₈ * 8 + d₉ * 9) % 11\n  ```\n\n## Sample Run 1\n```\nEnter the first 9 digits of an ISBN as a string: 3601267\nIncorrect input. It must have exact 9 digits\n```\n\n## Sample Run 2\n```\nEnter the first 9 digits of an ISBN as a string: 013601267\nThe ISBN-10 number is 0136012671\n```\n\n## Sample Run 3\n```\nEnter the first 9 digits of an ISBN as a string: 013031997\nThe ISBN-10 number is 013031997X\n```\n---\n```python\nisbn9 = input(\'Enter the first 9 digits of an ISBN as a string:\')\n\nif len(isbn9) != 9:\n    print(\'Incorrect input. It must have exac ...
#  [Document(id_='73a544ce-f8ea-450e-93ec-ac0711e9107b', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='# Objectives for class 7\n\n## --- Chapter 4 ---\n\n### 4.1\nTo solve mathematics problems by using the functions in the math module (§4.2)\n\n### 4.2\nTo represent and process strings and characters (§4.3)\n\n### 4.3\nTo encode characters using ASCII and Unicode (§4.3.1)\n\n### 4.4\nTo use the `ord` function to obtain a numerical code for a character and the `chr` function to convert a numerical code to a character (§4.3.2)\n\n### 4.5\nTo represent special characters using the escape sequence (§4.3.3)\n\n### 4.6\nTo test substrings using the `in` and `not in` operators (§4.3.8)\n\n### 4.7\nTo compare strings (§4.3.9)\n\n### 4.8\nTo use string functions `min`, `max`, and `len` (§4.3.10)\n---\n# Solve math problems using Python Built-in Functions\n\n```python\n>>> max(2, 3, 4)  # Returns a maximum number\n4\n\n>>> min(2, 3, 4)  # Returns a minimum number\n2\n\n>>> round(4.51)  # Rounds to its nearest integer\n5\n\n>>> round(4.4)  # Rounds to its nearest integer\n4\n\n>>> abs(-3)  # Returns the absolute value\n3\n\n>>> pow(2, 3)  # Same as 2 ** 3\n8\n```\n---\n# Solve math problems using the math Functions\n\n| Function      | Description                                                                 | Example                        |\n|---------------|-----------------------------------------------------------------------------|--------------------------------|\n| `fabs(x)`     | Returns the absolute value of the argument.                                 | `fabs(-2)` is 2                |\n| `ceil(x)`     | Rounds x up to its nearest integer and returns this integer.                | `ceil(2.1)` is 3               |\n|               |                                                                             | `ceil(-2.1)` is -2             |\n| `floor(x)`    | Rounds x down to its nearest integer and returns this integer.              | `floor(2.1)` is 2              |\n|               |                                                                             | `floor(-2.1)` is -3            |\n| `exp(x)`      | Returns the exponential function of x (e ** x).                             | `exp(1)` is 2.71828            |\n| `log(x)`      | Returns the natural logarithm of x.                                         | `log(2.71828)` is 1.0          |\n| `log(x, base)`| Returns the logarithm of x for the specified base.                          | `log10(10, 10)` is 1           |\n| `sqrt(x)`     | Returns the square root of x.                                               | `sqrt(4.0)` is 2               |\n| `sin(x)`      | Returns the sine of x. x represents an angle in radians.                    | `sin(3.14159 / 2)` is 1        |\n|               |                                                                             | `sin(3.14159)` is 0            |\n| `asin(x)`     | Returns the angle in radians for the inverse of sine.                       | `asin(1.0)` is 1.57            |\n|               |                                                                             | `asin(0.5)` is 0.523599        |\n| `cos(x)`      | Returns the cosine of x. x represents an angle in radians.                  | `cos(3.14159 / 2)` is 0        |\n|               |                                                                             | `cos(3.14159)` is -1           |\n---\n\n| Function       | Description                                                                 | Example                        |\n|----------------|-----------------------------------------------------------------------------|--------------------------------|\n| `acos(x)`      | Returns the angle in radians for the inverse of cosine.                     | `acos(1.0)` is 0               |\n|                |                                                                            ...

# %% [markdown]
# ### Create Chunks using LlamaIndex

# %%
def chunk(md):
    node_parser_OPENAI = MarkdownElementNodeParser_mod(
        llm=OpenAI(model="gpt-4"), num_workers=8, 
    )
    nodes_OA = []
    base_nodes_OA  = []
    objects_OA  = []

    for doc in md:
        pdoc_OA = node_parser_OPENAI.get_nodes_from_documents(doc)
        nodes_OA.append(pdoc_OA)
        base, obj = node_parser_OPENAI.get_nodes_and_objects(pdoc_OA)
        base_nodes_OA.append(base)
        objects_OA.append(obj)
    base_nodes_OA_list = list(itertools.chain(*base_nodes_OA))
    objects_OA_list = list(itertools.chain(*objects_OA))

    await SummaryExtractor().acall(base_nodes_OA_list)
    await TitleExtractor().acall(base_nodes_OA_list+objects_OA_list)
return base_nodes_OA,objects_OA

# %%
base_nodes_OA, objects_OA = chunk(md)

# %% [markdown]
# ### Serialize

# %%
from rag_tools.serialize_doc import serialize_

# %%
text_chunk = serialize_.serialize_text_chunk(base_nodes_OA)
obj_chunk = serialize_.serialize_object_chunk(objects_OA)

# %%
cf = serialize_.combine_chunk(text_chunk,obj_chunk)

# %%
cf[1]
# Out:
# [{'section_summary': 'In this section, the objectives for class 7 include learning how to solve mathematics problems using functions in the math module, representing and processing strings and characters, encoding characters using ASCII and Unicode, using the `ord` and `chr` functions, representing special characters using escape sequences, testing substrings using `in` and `not in` operators, comparing strings, and using string functions such as `min`, `max`, and `len`. Additionally, students will learn how to solve math problems using Python built-in functions like `max`, `min`, `round`, `abs`, and `pow`, as well as using math functions for more complex mathematical operations.',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 0,
#   'end_char_idx': 1071},
#  {'section_summary': 'The table provides a list of mathematical functions, their descriptions, and examples of their usage.,\nwith the following columns:\n- Function: Names of the mathematical functions.\n- Description: Descriptions of what each function does.\n- Example: Examples of how to use each function.\n',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 1073,
#   'end_char_idx': 3265},
#  {'section_summary': 'The table provides descriptions and examples of various mathematical functions, including trigonometric functions and conversions between radians and degrees.,\nwith the following columns:\n- Function: Names of mathematical functions\n- Description: Descriptions of what each function does\n- Example: Examples of how to use each function\n',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 3271,
#   'end_char_idx': 4440},
#  {'section_summary': 'In this section, we learned about the math library in Python, which allows us to perform mathematical functions. We imported the math module and tested various algebraic and trigonometric functions such as exp, log, sqrt, sin, cos, and tan. We also explored how strings are represented in Python as sequences of characters, and how characters are assigned codes in Unicode/ASCII. The ASCII table and description were also discussed, highlighting the encoding of characters into bytes.',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 4442,
#   'end_char_idx': 5757},
#  {'section_summary': 'The table provides a comprehensive list of ASCII (American Standard Code for Information Interchange) codes in decimal (Dec), hexadecimal (Hx), and octal (Oct) format, along with their corresponding characters (Char) and descriptions. It also includes HTML representations for each character.,\nwith the following columns:\n- Dec: Represents the ASCII code in decimal format\n- Hx: Represents the ASCII code in hexadecimal format\n- Oct: Represents the ASCII code in octal format\n- Char: Represents the corresponding character for the ASCII code\n- Description: Provides a brief description or name for the corresponding ASCII character\n- Html: Represents the HTML code for the corresponding ASCII character\n',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 5759,
#   'end_char_idx': 11356},
#  {'section_summary': 'This section discusses the differences between Unicode and ASCII, highlighting that Unicode represents 65,536 distinct characters while ASCII represents 256 distinct characters. It also explains that ASCII is a subset of Unicode and that Python encodes characters using Unicode. The section introduces the `ord` function to obtain the Unicode of a character and the `chr` function to obtain a character by its Unicode. It also demonstrates how to represent special characters using escape sequences. Overall, the section provides a basic understanding of Unicode, ASCII, and character encoding in Python.',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 11358,
#   'end_char_idx': 12196},
#  {'section_summary': 'The table provides a list of common escape sequences, their corresponding descriptions, and Unicode representations.,\nwith the following columns:\n- Description: Describes the function of the escape sequence.\n- Escape Sequence: Shows the escape sequence symbol.\n- Unicode: Provides the Unicode equivalent of the escape sequence.\n',
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 12198,
#   'end_char_idx': 12638},
#  {'section_summary': "In this section, we learned about the `in` and `not in` operators in Python, specifically for comparing strings. We also discussed how to compare two strings by comparing the characters' numeric codes from left to right. Additionally, we explored some built-in functions for strings such as `len()`, `max()`, and `min()`.\n\nKey topics and entities covered in this section include:\n- `in` and `not in` operators for string comparison\n- Comparing two strings based on characters' numeric codes\n- Built-in functions for strings like `len()`, `max()`, and `min()`",
#   'document_title': '"Mastering String Manipulation and Character Encoding in Python: A Comprehensive Guide to Diversity, Uniqueness, Unicode, ASCII, and Built-in Functions"',
#   'start_char_idx': 12639,
#   'end_char_idx': 13355}]

# %%
doc_full = serialize_.serialize_doc(cf,md,files[:2])

# %%
doc_full[0]
# Out:
# {'filename': 'GSU - CIS 3260 - Fall 2023/Lecture Slides Parsed/Week 14.pkl',
#  'title': 'Lecture Slides Parsed/Week 14',
#  'content': '# Objectives for class 14\n\n- Review IA4-IA7\n- Review Quiz 3 – Quiz 5\n- Final Exam Schedule\n- Group Project Schedule\n---\n# Individual Assignment 4 - 2\n\n- Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.\n\n## Sample Run\n```\nEnter a letter grade: B\nThe numeric value for grade B is 80\n```\n\n```python\nletter = input("Enter a letter grade: ")\n\nif letter in \'Aa\':\n    print("The numeric value for grade A is 90")\nelif letter in \'Bb\':\n    print("The numeric value for grade B is 80")\nelif letter in \'Cc\':\n    print("The numeric value for grade C is 70")\nelif letter in \'Dd\':\n    print("The numeric value for grade D is 60")\nelse:\n    print(letter, "is an invalid grade")\n```\n\n- Letter in “Aa”\n- Multiple way if statements\n---\n# Individual Assignment 4 - 3\n\n- Display number of days in the month.\n\n## Sample Run\n```\nEnter a year: 2001\nEnter a month: Jan\nJan 2001 has 31 days\n```\n\nA year is a **leap** year if **either** of the following conditions is satisfied:\n- The year is multiple of 400.\n  - `(year % 400) == 0` (in python)\n- The year is multiple of 4 and not multiple of 100.\n  - `(year % 4) == 0 and (year % 100) != 0` (in python)\n\n```python\nyear = int(input("Enter a year: "))\nmonth = input("Enter a month (first three letters with the first letter in uppercase): ")\n\nif month == "Jan" or month == "Mar" or month == "May" \\\nor month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":\n    print(month, year, "has 31 days")\nelif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":\n    print(month, year, "has 30 days")\nelif month == "Feb":\n    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):\n        print(month, year, "has 29 days")\n    else:\n        print(month, year, "has 28 days")\nelse:\n    print(month, "is not a correct month name")\n```\n---\n# Individual Assignment 5 - 1\n\n- Prompts the user to enter a string and displays its length and its first character.\n\n## Sample Run\n\n```\nEnter a string: Programming is fun\nThe length of string "Programming is fun" is 18\nThe last character of string Programming is fun is n\n```\n\n## Code\n\n```python\ns = input("Enter a string: ")\n\nprint("The length of string \\"Programming is fun\\" is ", len(s))\n\nprint("The last character of string Programming is fun is ", s[-1])\n```\n---\n# Individual Assignment 5 - 2\n\n- **Decide major and year**\n  - M: Mathematics\n  - C: Computer Science\n  - I: Information Technology\n\n## Sample Run\n```\nEnter two characters: M1\nMathematics\nFreshman\n```\n\n```python\n# More efficient with list created\ns = input("Enter two characters: ")\n\nms = [\'M\', \'C\', \'I\']\nmajors = [\'Mathematics\', \'Computer Science\', \'Information Technology\']\nyears = [\'Freshman\', \'Sophomore\', \'Junior\', \'Senior\']\n\nyear = int(s[1])\nmajor = majors[ms.index(s[0])]\n\nprint(major)\nprint(years[year - 1])\n```\n---\n# Individual Assignment 5 - 3\n\n- **An ISBN-9 to ISBN-10 converter (without function)**\n\n  If the checksum is 10, the last digit is denoted as X according to the ISBN-10 convention.\n\n  ```\n  checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d₄ * 4 + d₅ * 5 + d₆ * 6 + d₇ * 7 + d₈ * 8 + d₉ * 9) % 11\n  ```\n\n## Sample Run 1\n```\nEnter the first 9 digits of an ISBN as a string: 3601267\nIncorrect input. It must have exact 9 digits\n```\n\n## Sample Run 2\n```\nEnter the first 9 digits of an ISBN as a string: 013601267\nThe ISBN-10 number is 0136012671\n```\n\n## Sample Run 3\n```\nEnter the first 9 digits of an ISBN as a string: 013031997\nThe ISBN-10 number is 013031997X\n```\n---\n```python\nisbn9 = input(\'Enter the first 9 digits of an ISBN as a string:\')\n\nif len(isbn9) != 9:\n    print(\'Incorrect input. It must have exact 9 digits\')\nelse:\n    sum = 0\n    for i in range(1, 10):\n        sum = sum + int(isbn9[i-1]) * i\n    sum = sum % 11\n\n    if sum == 10:\n        d10 =  ...
#  'chunks': [{'section_summary': 'In this section, the key topics covered include reviewing previous assignments and quizzes, discussing the final exam schedule, and group project schedule. \n\nThe individual assignments focus on different tasks such as converting letter grades to numeric values, determining the number of days in a month, displaying the length and first character of a string, deciding a major and year based on input characters, and converting an ISBN-9 to an ISBN-10 without using a function.\n\nOverall, the section emphasizes problem-solving skills, conditional statements, string manipulation, and mathematical calculations.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 0,
#    'end_char_idx': 3228},
#   {'section_summary': 'This section includes three different Python programs as individual assignments. \n\n1. The first program is an ISBN-9 to ISBN-10 converter. It takes the first 9 digits of an ISBN as input, calculates the checksum based on a specific formula, and converts it to an ISBN-10 number. The program includes a function for the conversion.\n\n2. The second program prompts the user to enter integers until the user inputs "End". It then calculates the number of even numbers entered and the average of all numbers entered.\n\n3. The third program counts the number of vowels and consonants in a given string.\n\nOverall, these programs demonstrate different functionalities such as mathematical calculations, string manipulation, and user input handling in Python.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 3025,
#    'end_char_idx': 5394},
#   {'section_summary': 'This section includes sample code snippets and explanations for individual assignments related to counting vowels and consonants in a string, calculating the number of days in years, converting temperatures between Celsius and Fahrenheit, and counting the number of given ratings in a list. The code snippets demonstrate how to implement these functionalities in Python, providing a clear understanding of the concepts involved. The section also includes sample runs for each assignment to showcase the expected input and output.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 5396,
#    'end_char_idx': 7818},
#   {'section_summary': 'The table provides a distribution of ratings from 0 to 5, along with their respective counts. It shows how many times each rating was given.,\nwith the following columns:\n- Rating: This column lists the ratings from 0 to 5.\n- Count: This column shows the number of times each rating was given.\n',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 7820,
#    'end_char_idx': 7965},
#   {'section_summary': 'In this section, we are working with ratings given by individuals and their corresponding names. We are calculating the counts of each rating given and displaying the highest and lowest ratings along with the names of the individuals who gave those ratings.\n\nWe are using lists to store the ratings and names, and then iterating through the ratings list to count the occurrences of each rating. Finally, we display the counts for each rating.\n\nAdditionally, we have some quiz questions related to string manipulation, character encoding, and basic programming concepts like loops and functions. These questions test our understanding of string operations, character manipulation, and basic programming logic.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 7967,
#    'end_char_idx': 10855},
#   {'section_summary': 'In this section, the key topics covered include obtaining substrings in a string using the slicing operator, duplicating strings using the repetition operator, introducing objects and methods, utilizing methods in the `str` class, programming with characters and strings, and invoking the `print` function with the `end` argument. These topics provide a foundation for understanding and manipulating strings in Python.\n\nAdditionally, the section introduces concepts related to loops in Chapter 5, such as executing statements repeatedly using a while loop, controlling loops with user confirmation and sentinel values, implementing counter-controlled loops with for loops, and using program control with break statements. These topics help in understanding how to efficiently control the flow of a program using loops.\n\nFurthermore, Chapter 6 delves into the concept of functions, covering aspects such as defining functions with formal parameters, understanding the differences between functions that return and do not return values, invoking functions with actual parameters, determining the scope of variables, and applying functions in software development and design. These topics are essential for modularizing code and improving code reusability.\n\nLastly, Chapter 7 focuses on lists in Python, discussing their usefulness in programming, creating lists, accessing list elements, obtaining sublists, traversing elements using loops, and utilizing various list methods. Understanding lists is crucial for working with collections of data efficiently in Python.\n\nOverall, the section provides a comprehensive overview of fundamental concepts in Python programming, including string manipulation, loop control, function definition and invocation, and list manipulation.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 10553,
#    'end_char_idx': 13784},
#   {'section_summary': 'The table provides a breakdown of points distribution across different programming and software development topics for a test or assignment. Each topic has points allocated for multiple choice questions, fill in the blanks, and problem-solving tasks. The total points for the test or assignment is 100.,\nwith the following columns:\n- Topic: Topics include loops, string concepts, function creation, 1D and 2D lists, and software development.\n- Multiple Choices: Points allocated for multiple choice questions.\n- Fill In blanks: Points allocated for fill in the blanks.\n- Problem Solving: Points allocated for problem-solving tasks.\n- Total: Total points for each topic.\n',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 13786,
#    'end_char_idx': 14815},
#   {'section_summary': 'The group project is due on Monday, December 11th at midnight. Students have the option to use Zoom or WebEx to record their presentation. This project likely involves collaboration with classmates to work on a specific assignment or task related to the course material. It is important for students to communicate effectively and work together to successfully complete the project on time.',
#    'document_title': 'Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count',
#    'start_char_idx': 14816,
#    'end_char_idx': 14939}]}

# %%
content = serialize_.content_for_embedding(cf,doc_full)

# %%
content[0]
# Out:
# ['section_summary: In this section, the key topics covered include reviewing previous assignments and quizzes, discussing the final exam schedule, and group project schedule. \n\nThe individual assignments focus on different tasks such as converting letter grades to numeric values, determining the number of days in a month, displaying the length and first character of a string, deciding a major and year based on input characters, and converting an ISBN-9 to an ISBN-10 without using a function.\n\nOverall, the section emphasizes problem-solving skills, conditional statements, string manipulation, and mathematical calculations.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: # Objectives for class 14\n\n- Review IA4-IA7\n- Review Quiz 3 – Quiz 5\n- Final Exam Schedule\n- Group Project Schedule\n---\n# Individual Assignment 4 - 2\n\n- Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.\n\n## Sample Run\n```\nEnter a letter grade: B\nThe numeric value for grade B is 80\n```\n\n```python\nletter = input("Enter a letter grade: ")\n\nif letter in \'Aa\':\n    print("The numeric value for grade A is 90")\nelif letter in \'Bb\':\n    print("The numeric value for grade B is 80")\nelif letter in \'Cc\':\n    print("The numeric value for grade C is 70")\nelif letter in \'Dd\':\n    print("The numeric value for grade D is 60")\nelse:\n    print(letter, "is an invalid grade")\n```\n\n- Letter in “Aa”\n- Multiple way if statements\n---\n# Individual Assignment 4 - 3\n\n- Display number of days in the month.\n\n## Sample Run\n```\nEnter a year: 2001\nEnter a month: Jan\nJan 2001 has 31 days\n```\n\nA year is a **leap** year if **either** of the following conditions is satisfied:\n- The year is multiple of 400.\n  - `(year % 400) == 0` (in python)\n- The year is multiple of 4 and not multiple of 100.\n  - `(year % 4) == 0 and (year % 100) != 0` (in python)\n\n```python\nyear = int(input("Enter a year: "))\nmonth = input("Enter a month (first three letters with the first letter in uppercase): ")\n\nif month == "Jan" or month == "Mar" or month == "May" \\\nor month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":\n    print(month, year, "has 31 days")\nelif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":\n    print(month, year, "has 30 days")\nelif month == "Feb":\n    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):\n        print(month, year, "has 29 days")\n    else:\n        print(month, year, "has 28 days")\nelse:\n    print(month, "is not a correct month name")\n```\n---\n# Individual Assignment 5 - 1\n\n- Prompts the user to enter a string and displays its length and its first character.\n\n## Sample Run\n\n```\nEnter a string: Programming is fun\nThe length of string "Programming is fun" is 18\nThe last character of string Programming is fun is n\n```\n\n## Code\n\n```python\ns = input("Enter a string: ")\n\nprint("The length of string \\"Programming is fun\\" is ", len(s))\n\nprint("The last character of string Programming is fun is ", s[-1])\n```\n---\n# Individual Assignment 5 - 2\n\n- **Decide major and year**\n  - M: Mathematics\n  - C: Computer Science\n  - I: Information Technology\n\n## Sample Run\n```\nEnter two characters: M1\nMathematics\nFreshman\n```\n\n```python\n# More efficient with list created\ns = input("Enter two characters: ")\n\nms = [\'M\', \'C\', \'I\']\nmajors = [\'Mathematics\', \'Computer Science\', \'Information Technology\']\nyears = [\'Freshman\', \'Sophomore\', \'Junior\', \'Senior\']\n\nyear = int(s[1])\nmajor = majors[ms.index(s[0])]\n\nprint(major)\nprint(years[year - 1])\n```\n---\n# Individual Assignment 5 - 3\n\n- **An ISBN-9 to ISBN-10 converter (without function)**\n\n  If the checksum is 10, the last digit is denoted as X according to the ISBN-10 convention.\n\n  ```\n  checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d ...
#  'section_summary: This section includes three different Python programs as individual assignments. \n\n1. The first program is an ISBN-9 to ISBN-10 converter. It takes the first 9 digits of an ISBN as input, calculates the checksum based on a specific formula, and converts it to an ISBN-10 number. The program includes a function for the conversion.\n\n2. The second program prompts the user to enter integers until the user inputs "End". It then calculates the number of even numbers entered and the average of all numbers entered.\n\n3. The third program counts the number of vowels and consonants in a given string.\n\nOverall, these programs demonstrate different functionalities such as mathematical calculations, string manipulation, and user input handling in Python.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: ```\n  checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d₄ * 4 + d₅ * 5 + d₆ * 6 + d₇ * 7 + d₈ * 8 + d₉ * 9) % 11\n  ```\n\n## Sample Run 1\n```\nEnter the first 9 digits of an ISBN as a string: 3601267\nIncorrect input. It must have exact 9 digits\n```\n\n## Sample Run 2\n```\nEnter the first 9 digits of an ISBN as a string: 013601267\nThe ISBN-10 number is 0136012671\n```\n\n## Sample Run 3\n```\nEnter the first 9 digits of an ISBN as a string: 013031997\nThe ISBN-10 number is 013031997X\n```\n---\n```python\nisbn9 = input(\'Enter the first 9 digits of an ISBN as a string:\')\n\nif len(isbn9) != 9:\n    print(\'Incorrect input. It must have exact 9 digits\')\nelse:\n    sum = 0\n    for i in range(1, 10):\n        sum = sum + int(isbn9[i-1]) * i\n    sum = sum % 11\n\n    if sum == 10:\n        d10 = \'X\'\n    else:\n        d10 = str(sum)\n    print("The ISBN-10 number is", isbn9 + d10)\n```\n---\n# Individual Assignment 6 - 3\n\n- An ISBN-9 to ISBN-10 converter (with function)\n\n```python\ndef isbn9toisbn10(isbn9):\n    sum=0\n    for i in range(1,10):\n        sum=sum+int(isbn9[i-1])*i\n    sum=sum%11\n\n    if sum == 10:\n        d10=\'X\'\n    else:\n        d10=str(sum)\n    return isbn9+d10\n\nisbn9=input(\'Enter the first 9 digits of an ISBN as a string:\')\n\nif len(isbn9)!=9:\n    print(\'Incorrect input. It must have exact 9 digits\')\nelse:\n    print("The ISBN-10 number is", isbn9toisbn10(isbn9))\n```\n---\n# Individual Assignment 6 - 1\n\n## Sample Run\n\n```\nEnter an integer, the input ends if user enters "End": 1\nEnter an integer, the input ends if user enters "End": 2\nEnter an integer, the input ends if user enters "End": -1\nEnter an integer, the input ends if user enters "End": 3\nEnter an integer, the input ends if user enters "End": 0\nEnter an integer, the input ends if user enters "End": End\n```\n\n**The number of even numbers is 2**\n\n**The average is 1.0**\n---\n```python\ns = input("Enter an integer, the input ends if user enters \\"End\\"")\ncount=0\nevencount=0\nsum=0\n\nwhile s!=\'End\':\n    num=int(s)\n    count=count+1\n    if num%2==0:\n        evencount=evencount+1\n    sum=sum+num\n    s = input("Enter an integer, the input ends if user enters \\"End\\"")\n\nif count==0:\n    print("No number entered")\nelse:\n    print("The number of even numbers is", evencount)\n    print("The average is", round(sum/count,2))\n```\n---\n# Individual Assignment 6 - 2\n\n- Displays the number of vowels and consonants in the string.',
#  'section_summary: This section includes sample code snippets and explanations for individual assignments related to counting vowels and consonants in a string, calculating the number of days in years, converting temperatures between Celsius and Fahrenheit, and counting the number of given ratings in a list. The code snippets demonstrate how to implement these functionalities in Python, providing a clear understanding of the concepts involved. The section also includes sample runs for each assignment to showcase the expected input and output.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: ## Sample Run\n```\nEnter a string: Programming is fun\nThe number of consonants is 11\nThe number of vowels is 5\n```\n\n```python\ns = input("Enter a string:")\nnvowels = 0\nncons = 0\nfor i in range(0, len(s)):\n    ch = s[i]\n    if ch.isalpha():\n        if ch in \'AEIOU\' or ch in \'aeiou\':\n            nvowels = nvowels + 1\n        else:\n            ncons = ncons + 1\n\nprint("The number of consonants is ", ncons)\nprint("The number of vowels is ", nvowels)\n```\n---\n# Individual Assignment 7 - 1\n\n- Display number of days in years\n\n## Sample Run\n```\nEnter a start year: 2000\nEnter an end year: 2005\nyear    days\n2000    366\n2001    365\n2002    365\n2003    365\n2004    366\n2005    365\n```\n\n```python\ndef isleapyear(year):\n    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)\n\ndef caldays(year):\n    if isleapyear(year):\n        return 366\n    else:\n        return 365\n\ndef main():\n    startyear = int(input("Enter a start year:"))\n    endyear = int(input("Enter an end year:"))\n\n    print("year", \'\\t\', "days")\n    for i in range(startyear, endyear + 1):\n        ndays = caldays(i)\n        print(i, \'\\t\', ndays)\n\nmain()\n```\n---\n# Individual Assignment 7 - 2\n\n```python\ndef celsiusToFahrenheit(celsius):\n    fahrenheit = (9 / 5) * celsius + 32\n    return fahrenheit\n\ndef fahrenheitToCelsius(fahrenheit):\n    celsius = (5 / 9) * (fahrenheit - 32)\n    return celsius\n```\n\n**convert.py**\n---\n# Individual Assignment 7 - 2\n\n```python\nimport convert\n\nprint("1. Convert Celsius to Fahrenheit")\nprint("2. Convert Fahrenheit to Celsius")\n\nchoice = int(input("Enter your choice (1 or 2):"))\n\nif choice == 1:\n    celsius = int(input("Enter a temperature in Celsius: "))\n    print("Fahrenheit is", int(convert.celsiusToFahrenheit(celsius)))\nelif choice == 2:\n    fahrenheit = int(input("Enter a temperature in Fahrenheit: "))\n    print("Celsius is", int(convert.fahrenheitToCelsius(fahrenheit)))\n```\n\n**File:** `test.py`\n---\n# Individual Assignment 8 - 1\n\n- Count the number of given ratings from the list.\n\n```python\nratings_list = [4, 5, 1, 2, 3, 5, 4, 2, 3, 1, 5, 4, 4, 3]\n\nrating = int(input("Please enter a rating:"))\n\ncount = ratings_list.count(rating)\n\nprint(count, "ratings from our data set are with value", rating)\n```\n\n**Sample Run 1**\n```\nPlease enter a rating: 5\n3 ratings from our data set are with value 5\n```\n---\n# Individual Assignment 8 - 2\n\n- **Count the frequency of ratings (0, 1, 2, 3, 4, 5)**\n\n## Sample Run',
#  'section_summary: The table provides a distribution of ratings from 0 to 5, along with their respective counts. It shows how many times each rating was given.,\nwith the following columns:\n- Rating: This column lists the ratings from 0 to 5.\n- Count: This column shows the number of times each rating was given.\n\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: | Rating | Count |\n|--------|-------|\n| Rating 0: | 1 |\n| Rating 1: | 2 |\n| Rating 2: | 2 |\n| Rating 3: | 3 |\n| Rating 4: | 4 |\n| Rating 5: | 3 |',
#  'section_summary: In this section, we are working with ratings given by individuals and their corresponding names. We are calculating the counts of each rating given and displaying the highest and lowest ratings along with the names of the individuals who gave those ratings.\n\nWe are using lists to store the ratings and names, and then iterating through the ratings list to count the occurrences of each rating. Finally, we display the counts for each rating.\n\nAdditionally, we have some quiz questions related to string manipulation, character encoding, and basic programming concepts like loops and functions. These questions test our understanding of string operations, character manipulation, and basic programming logic.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: ```python\nratings_list = [4, 5, 1, 2, 3, 5, 4, 2, 3, 1, 5, 4, 4, 3]\ncounts = [0] * 5\n\nfor i in range(0, len(ratings_list)):\n    counts[ratings_list[i] - 1] = counts[ratings_list[i] - 1] + 1\n\nfor i in range(0, len(counts)):\n    print("Rating", i + 1, ":", counts[i])\n```\n---\n# Individual Assignment 8 - 3\n\n- Displays the person(s) who gives the highest rating, and the person(s) who gives the lowest rating\n\n```python\nratings_list = [4, 5, 1, 2, 3, 5, 4, 2, 3, 1, 5, 4, 4, 3]\nnames_list = ["john", "alex", "anna", "max", "allen", "bria", "david", "jane", "cathy", "jecissa", "grace", "nick", "paul", "hans"]\n```\n\n## Sample Run\n\n```\nHighest rating is 5, given by alex, bria, grace\nLowest rating is 1, given by anna, jecissa\n```\n---\n\n\n---\n# Quiz 3\n\n- Check if `c` is a newline character.\n\n```python\nc == \'\\n\'\n```\n---\n\n- Assume we have assigned values to a list of variables below.\n\n\n---\n\n# Quiz 4\n\nWill the following program terminate?\n\n\n---\n# Quiz 4\n\n- **What is the output of the following code?**\n\n```python\ncount = 1\nwhile count < 2:\n    count += 1\n    print(count, end = \' \')\n```\n\n**Answer is 2**\n---\n# Quiz 4\n\nSuppose that s1 and s2 are two strings, given as follows:\n```\ns1 = "Welcome to Python"\ns2 = "1234"\n```\nWhat are the results of the following expressions?\n\na. `s1[0]` _______ W _______\n\nb. `s1[:3]` _______ Wel _______\n\nc. `s1[1:3]` _______ el _______\n\nd. `len(s2)` _______ 4 _______\n\ne. `s2*2` _______ 12341234 _______\n\nf. `s1.count(\'o\')` _______ 3 _______\n\ng. `s1.isupper()` _______ False _______\n\nh. `s2.isdigit()` _______ True _______\n---\n# Quiz 5\n\nGiven the following function, what will be displayed by the call `nPrint(n=4, message=\'a\')`?\n\n```python\ndef nPrint(message, n):\n    while n > 0:\n        print(message, end=\' \')\n        n -= 1\n```\n\n**Answer should be infinite loop**\n---\n# Objectives covered in Final Exam\n\n## --- Chapter 4 ---\n\n- **4.1** To solve mathematics problems by using the functions in the math module (§4.2)\n- **4.2** To represent and process strings and characters (§4.3)\n- **4.3** To encode characters using ASCII and Unicode (§4.3.1)\n- **4.4** To use the `ord` function to obtain a numerical code for a character and the `chr` function to convert a numerical code to a character (§4.3.2)\n- **4.5** To represent special characters using the escape sequence (§4.3.3)\n- **4.6** To test substrings using the `in` and `not in` operators (§4.3.8)\n- **4.7** To compare strings (§4.3.9)\n- **4.8** To use string functions `min`, `max`, and `len` (§4.3.10)\n---\n\n- 4.9 To obtain a character in a string using the index operator `[]` (§[4.3.11](#4.3.11)).\n- 4.10 To obtain a substring in a string using the slicing operator `[start:end]` (§[4.3.12](#4.3.12)).\n- 4.11 Use repetition operator `*` to duplicate strings (§[4.3.6](#4.3.6)).\n- 4.12 To introduce objects and methods (§[4.5](#4.5)).\n- 4.13 To introduce the methods in the `str` class (§[4.6](#4.6)).',
#  'section_summary: In this section, the key topics covered include obtaining substrings in a string using the slicing operator, duplicating strings using the repetition operator, introducing objects and methods, utilizing methods in the `str` class, programming with characters and strings, and invoking the `print` function with the `end` argument. These topics provide a foundation for understanding and manipulating strings in Python.\n\nAdditionally, the section introduces concepts related to loops in Chapter 5, such as executing statements repeatedly using a while loop, controlling loops with user confirmation and sentinel values, implementing counter-controlled loops with for loops, and using program control with break statements. These topics help in understanding how to efficiently control the flow of a program using loops.\n\nFurthermore, Chapter 6 delves into the concept of functions, covering aspects such as defining functions with formal parameters, understanding the differences between functions that return and do not return values, invoking functions with actual parameters, determining the scope of variables, and applying functions in software development and design. These topics are essential for modularizing code and improving code reusability.\n\nLastly, Chapter 7 focuses on lists in Python, discussing their usefulness in programming, creating lists, accessing list elements, obtaining sublists, traversing elements using loops, and utilizing various list methods. Understanding lists is crucial for working with collections of data efficiently in Python.\n\nOverall, the section provides a comprehensive overview of fundamental concepts in Python programming, including string manipulation, loop control, function definition and invocation, and list manipulation.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: - 4.10 To obtain a substring in a string using the slicing operator `[start:end]` (§[4.3.12](#4.3.12)).\n- 4.11 Use repetition operator `*` to duplicate strings (§[4.3.6](#4.3.6)).\n- 4.12 To introduce objects and methods (§[4.5](#4.5)).\n- 4.13 To introduce the methods in the `str` class (§[4.6](#4.6)).\n- 4.14 To program using characters and strings (§[4.7.1](#4.7.1)).\n- 4.15 To invoke the `print` function with the `end` argument (§[4.3.4](#4.3.4)).\n\n---\n\n--- Chapter 5 ---\n\n- 5.1 To write programs for executing statements repeatedly using a while loop (§5.2).\n- 5.2 To control a loop with the user’s confirmation and a sentinel value (§5.5).\n- 5.3 To develop loops following the loop design strategy (§5.4).\n- 5.4 To use for loops to implement counter-controlled loops (§5.6).\n- 5.6 To implement program control with break. (§5.10).\n\n---\n\n# --- Chapter 6 ---\n\n- 6.1 To understand what is a function (§6.1)\n- 6.2 To define functions with formal parameters (§6.2)\n- 6.3 To distinguish the differences between the functions that return and do not return a value (§6.4)\n- 6.4 To invoke functions with actual parameters (i.e., arguments) (§6.3)\n- 6.5 To determine the scope of variables (§6.8)\n- 6.6 To invoke a function using positional arguments or keyword arguments (§6.5)\n- 6.7 To invoke functions defined from another program (§6.7)\n- 6.8 To apply the concept of function in software development and design (§6.13)\n\n---\n\n# --- Chapter 7 ---\n\n- **7.1** To describe why lists are useful in programming (§[7.1](#)).\n- **7.2** To learn how to create lists (§[7.2](#)).\n- **7.3** To use the len, min, max, sum, and random.shuffle functions with a list (§[7.2.2](#)).\n- **7.4** To access list elements by using indexed variables (§[7.2.3](#)).\n- **7.5** To obtain a sublist from a larger list by using the slicing operator [start : end : step] (§[7.2.4](#)).\n- **7.6** To use the + (concatenation), * (repetition), and in/not in operator.\n- **7.7** To traverse elements in a list using a for loop (§[7.2.6](#)).\n- **7.8** To  ...
#  'section_summary: The table provides a breakdown of points distribution across different programming and software development topics for a test or assignment. Each topic has points allocated for multiple choice questions, fill in the blanks, and problem-solving tasks. The total points for the test or assignment is 100.,\nwith the following columns:\n- Topic: Topics include loops, string concepts, function creation, 1D and 2D lists, and software development.\n- Multiple Choices: Points allocated for multiple choice questions.\n- Fill In blanks: Points allocated for fill in the blanks.\n- Problem Solving: Points allocated for problem-solving tasks.\n- Total: Total points for each topic.\n\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: |                                      | Multiple Choices | Fill In blanks | Problem Solving | Total |\n|--------------------------------------|------------------|----------------|-----------------|-------|\n| For loop and range function          | 4                | 0              | 2               | 6     |\n| While loop                           | 2                | 0              | 0               | 2     |\n| String concepts and string processing| 6                | 5              | 3               | 14    |\n| Function creation and call           | 12               | 5              | 0               | 17    |\n| 1D list                              | 4                | 10             | 2               | 16    |\n| 2D list                              | 2                | 0              | 0               | 2     |\n| Software Development [System analysis, System Design, Implementation] | 0 | 0 | 43 | 43 |\n| **Total**                            | **30**           | **20**         | **50**          | **100 (Points)** |',
#  'section_summary: The group project is due on Monday, December 11th at midnight. Students have the option to use Zoom or WebEx to record their presentation. This project likely involves collaboration with classmates to work on a specific assignment or task related to the course material. It is important for students to communicate effectively and work together to successfully complete the project on time.\n\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count\n\ncontent: ---\n# Group Project\n\n- Due on Monday midnight, Dec. 11<sup>th</sup>\n- You can use Zoom or WebEx to record your presentation']

# %%
print(content[0][6])
# Out:
# section_summary: The table provides a breakdown of points distribution across different programming and software development topics for a test or assignment. Each topic has points allocated for multiple choice questions, fill in the blanks, and problem-solving tasks. The total points for the test or assignment is 100.,
# with the following columns:
# - Topic: Topics include loops, string concepts, function creation, 1D and 2D lists, and software development.
# - Multiple Choices: Points allocated for multiple choice questions.
# - Fill In blanks: Points allocated for fill in the blanks.
# - Problem Solving: Points allocated for problem-solving tasks.
# - Total: Total points for each topic.
#
#
# document_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Rating Frequency Count
#
# content: |                                      | Multiple Choices | Fill In blanks | Problem Solving | Total |
# |--------------------------------------|------------------|----------------|-----------------|-------|
# | For loop and range function          | 4                | 0              | 2               | 6     |
# | While loop                           | 2                | 0              | 0               | 2     |
# | String concepts and string processing| 6                | 5              | 3               | 14    |
# | Function creation and call           | 12               | 5              | 0               | 17    |
# | 1D list                              | 4                | 10             | 2               | 16    |
# | 2D list                              | 2                | 0              | 0               | 2     |
# | Software Development [System analysis, System Design, Implementation] | 0 | 0 | 43 | 43 |
# | **Total**                            | **30**           | **20**         | **50**          | **100 (Points)** |

# %% [markdown]
# ### Send to LLM/Embedding Model

# %%
import rag_tools.utils

# %%
rag_tools.utils.embed_nodes(base_nodes_OA[0],
                            embed_model= OpenAIEmbedding())
# Out:
# {'9371e839-7327-4c8d-b877-2a49fd17d242': [0.012948758900165558,
#   0.0022825654596090317,
#   0.01547309197485447,
#   -0.04823964089155197,
#   -0.031059956178069115,
#   0.0195689108222723,
#   -0.02312430739402771,
#   -0.024717126041650772,
#   -0.031230615451931953,
#   -0.01135594118386507,
#   0.027732104063034058,
#   0.00610106298699975,
#   -0.0314297191798687,
#   0.043859388679265976,
#   -0.004362473264336586,
#   -0.010218213312327862,
#   0.004860228858888149,
#   -0.005628195125609636,
#   -0.007565886713564396,
#   -0.006161504425108433,
#   0.003628283506259322,
#   0.0005253100534901023,
#   -0.01124216802418232,
#   -0.0067836991511285305,
#   -0.008348074741661549,
#   -0.0029420917853713036,
#   -0.015771744772791862,
#   -0.040645308792591095,
#   0.01779121160507202,
#   -0.0013963825767859817,
#   0.010566642507910728,
#   -0.018274744972586632,
#   -0.018641674891114235,
#   -0.025607625022530556,
#   -0.01504589058458805,
#   0.0051504322327673435,
#   0.003454773221164942,
#   -0.02034791000187397,
#   0.017443079501390457,
#   -0.001854296657256782,
#   0.009327887557446957,
#   -0.038496047258377075,
#   0.004417174495756626,
#   0.19369292259216309,
#   -0.004551135003566742,
#   0.008305557072162628,
#   0.016145776957273483,
#   -0.009384292177855968,
#   0.016808530315756798,
#   0.017795607447624207,
#   0.004307890776544809,
#   -0.004699196666479111,
#   0.014933081343770027,
#   -0.02091195434331894,
#   0.003239731304347515,
#   4.384565545478836e-05,
#   -0.0056298705749213696,
#   0.03169930726289749,
#   0.007032931316643953,
#   -0.02572043426334858,
#   -0.04354424402117729,
#   -0.015906058251857758,
#   -0.002444780897349119,
#   0.003930686041712761,
#   -0.0002035848592640832,
#   0.006518240552395582,
#   -0.030543016269803047,
#   0.031050655990839005,
#   -0.01644190028309822,
#   -0.016004765406250954,
#   0.01484847441315651,
#   -0.0026668733917176723,
#   0.0068460917100310326,
#   0.0012884894385933876,
#   -0.030543016269803047,
#   0.014087014831602573,
#   0.010893112048506737,
#   -0.0280753206461668,
#   -0.007692158687859774,
#   0.0228579081594944,
#   -0.011978897266089916,
#   0.019276224076747894,
#   0.006391330622136593,
#   -0.005439505446702242,
#   -0.011443055234849453,
#   0.008686287328600883,
#   -0.012916621752083302,
#   0.018486563116312027,
#   -0.008242102339863777,
#   ...]}

# %%
from llama_index.core.schema import BaseNode, ImageNode, MetadataMode

# %%
base_nodes_OA[0][0].get_content(metadata_mode=MetadataMode.EMBED)
# Out:
# '[Excerpt from document]\nsection_summary: In this section, the key topics covered include reviewing previous assignments and quizzes, discussing the final exam schedule, and group project schedule. \n\nThe individual assignments in this section focus on various tasks such as converting letter grades to numeric values, determining the number of days in a given month, calculating the length of a string and displaying its first and last characters, and deciding a major and year based on user input. \n\nAdditionally, there is an assignment that involves converting a 9-digit ISBN to a 10-digit ISBN following a specific checksum calculation formula. \n\nOverall, the section covers a range of programming tasks and concepts related to conditional statements, string manipulation, and mathematical calculations.\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Ratings Frequency Analysis\ncontent: # Objectives for class 14\n\n- Review IA4-IA7\n- Review Quiz 3 – Quiz 5\n- Final Exam Schedule\n- Group Project Schedule\n---\n# Individual Assignment 4 - 2\n\n- Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.\n\n## Sample Run\n```\nEnter a letter grade: B\nThe numeric value for grade B is 80\n```\n\n```python\nletter = input("Enter a letter grade: ")\n\nif letter in \'Aa\':\n    print("The numeric value for grade A is 90")\nelif letter in \'Bb\':\n    print("The numeric value for grade B is 80")\nelif letter in \'Cc\':\n    print("The numeric value for grade C is 70")\nelif letter in \'Dd\':\n    print("The numeric value for grade D is 60")\nelse:\n    print(letter, "is an invalid grade")\n```\n\n- Letter in “Aa”\n- Multiple way if statements\n---\n# Individual Assignment 4 - 3\n\n- Display number of days in the month.\n\n## Sample Run\n```\nEnter a year: 2001\nEnter a month: Jan\nJan 2001 has 31 days\n```\n\nA year is a **leap** year if **either** of the following conditions is satisfied:\n- The year is multiple of 400.\n  - `(year % 400) == 0` (in python)\n- The year is multiple of 4 and not multiple of 100.\n  - `(year % 4) == 0 and (year % 100) != 0` (in python)\n\n```python\nyear = int(input("Enter a year: "))\nmonth = input("Enter a month (first three letters with the first letter in uppercase): ")\n\nif month == "Jan" or month == "Mar" or month == "May" \\\nor month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":\n    print(month, year, "has 31 days")\nelif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":\n    print(month, year, "has 30 days")\nelif month == "Feb":\n    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):\n        print(month, year, "has 29 days")\n    else:\n        print(month, year, "has 28 days")\nelse:\n    print(month, "is not a correct month name")\n```\n---\n# Individual Assignment 5 - 1\n\n- Prompts the user to enter a string and displays its length and its first character.\n\n## Sample Run\n\n```\nEnter a string: Programming is fun\nThe length of string "Programming is fun" is 18\nThe last character of string Programming is fun is n\n```\n\n## Code\n\n```python\ns = input("Enter a string: ")\n\nprint("The length of string \\"Programming is fun\\" is ", len(s))\n\nprint("The last character of string Programming is fun is ", s[-1])\n```\n---\n# Individual Assignment 5 - 2\n\n- **Decide major and year**\n  - M: Mathematics\n  - C: Computer Science\n  - I: Information Technology\n\n## Sample Run\n```\nEnter two characters: M1\nMathematics\nFreshman\n```\n\n```python\n# More efficient with list created\ns = input("Enter two characters: ")\n\nms = [\'M\', \'C\', \'I\']\nmajors = [\'Mathematics\', \'Computer Science\', \'Information Technology\']\nyears = [\'Freshman\', \'Sophomore\', \'Junior\', \'Senior\']\n\nyear = int(s[1])\nmajor = majors[ms.index(s[0])]\n\nprint(major)\nprint(years[year - 1])\n```\n---\n# Individual Assignment 5 - 3\n\n- **An ISBN-9 to ISBN-10 ...

# %%
objects_OA[0][0].get_content(metadata_mode=MetadataMode.EMBED)
# Out:
# '[Excerpt from document]\ndocument_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Ratings Frequency Analysis\nExcerpt:\n-----\nThe table provides a distribution of ratings from 0 to 5, along with their respective counts.,\nwith the following columns:\n- Rating: This column lists the ratings from 0 to 5.\n- Count: This column shows the count of each rating.\n\n-----'

# %%
print(base_nodes_OA[0][0].get_content(metadata_mode=MetadataMode.EMBED))
# Out:
# [Excerpt from document]
# section_summary: In this section, the key topics covered include reviewing previous assignments and quizzes, discussing the final exam schedule, and group project schedule.
#
# The individual assignments in this section focus on various tasks such as converting letter grades to numeric values, determining the number of days in a given month, calculating the length of a string and displaying its first and last characters, and deciding a major and year based on user input.
#
# Additionally, there is an assignment that involves converting a 9-digit ISBN to a 10-digit ISBN following a specific checksum calculation formula.
#
# Overall, the section covers a range of programming tasks and concepts related to conditional statements, string manipulation, and mathematical calculations.
# document_title: Python Programming Concepts and Techniques: ISBN Conversion, String Analysis, and Ratings Frequency Analysis
# content: # Objectives for class 14
#
# - Review IA4-IA7
# - Review Quiz 3 – Quiz 5
# - Final Exam Schedule
# - Group Project Schedule
# ---
# # Individual Assignment 4 - 2
#
# - Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.
#
# ## Sample Run
# ```
# Enter a letter grade: B
# The numeric value for grade B is 80
# ```
#
# ```python
# letter = input("Enter a letter grade: ")
#
# if letter in 'Aa':
#     print("The numeric value for grade A is 90")
# elif letter in 'Bb':
#     print("The numeric value for grade B is 80")
# elif letter in 'Cc':
#     print("The numeric value for grade C is 70")
# elif letter in 'Dd':
#     print("The numeric value for grade D is 60")
# else:
#     print(letter, "is an invalid grade")
# ```
#
# - Letter in “Aa”
# - Multiple way if statements
# ---
# # Individual Assignment 4 - 3
#
# - Display number of days in the month.
#
# ## Sample Run
# ```
# Enter a year: 2001
# Enter a month: Jan
# Jan 2001 has 31 days
# ```
#
# A year is a **leap** year if **either** of the following conditions is satisfied:
# - The year is multiple of 400.
#   - `(year % 400) == 0` (in python)
# - The year is multiple of 4 and not multiple of 100.
#   - `(year % 4) == 0 and (year % 100) != 0` (in python)
#
# ```python
# year = int(input("Enter a year: "))
# month = input("Enter a month (first three letters with the first letter in uppercase): ")
#
# if month == "Jan" or month == "Mar" or month == "May" \
# or month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":
#     print(month, year, "has 31 days")
# elif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":
#     print(month, year, "has 30 days")
# elif month == "Feb":
#     if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#         print(month, year, "has 29 days")
#     else:
#         print(month, year, "has 28 days")
# else:
#     print(month, "is not a correct month name")
# ```
# ---
# # Individual Assignment 5 - 1
#
# - Prompts the user to enter a string and displays its length and its first character.
#
# ## Sample Run
#
# ```
# Enter a string: Programming is fun
# The length of string "Programming is fun" is 18
# The last character of string Programming is fun is n
# ```
#
# ## Code
#
# ```python
# s = input("Enter a string: ")
#
# print("The length of string \"Programming is fun\" is ", len(s))
#
# print("The last character of string Programming is fun is ", s[-1])
# ```
# ---
# # Individual Assignment 5 - 2
#
# - **Decide major and year**
#   - M: Mathematics
#   - C: Computer Science
#   - I: Information Technology
#
# ## Sample Run
# ```
# Enter two characters: M1
# Mathematics
# Freshman
# ```
#
# ```python
# # More efficient with list created
# s = input("Enter two characters: ")
#
# ms = ['M', 'C', 'I']
# majors = ['Mathematics', 'Computer Science', 'Information Technology']
# years = ['Freshman', 'Sophomore', 'Junior', 'Senior']
#
# year = int(s[1])
# major = majors[ms.index(s[0])]
#
# print(major)
# print(years[year - 1])
# ```
# ---
# # Individual Assignment 5 - 3
#
# - **An ISBN-9 to ISBN-10 converter (without function)**
#
#   If the checksum is 10, the last digit is denoted as X according to the ISBN-10 convention.
#
#   ```
#   checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d₄ * 4 + d₅ * 5 + d₆ * 6 + d₇ * 7 + d₈ * 8 + d₉ * 9) % 11
#   ```
#
# ## Sample Run 1
# ```
# Enter the first 9 digits of an ISBN as a string: 3601267
# Incorrect input.
# start_char_idx: 0
# end_char_idx: 3228
# Excerpt:
# -----
# # Objectives for class 14
#
# - Review IA4-IA7
# - Review Quiz 3 – Quiz 5
# - Final Exam Schedule
# - Group Project Schedule
# ---
# # Individual Assignment 4 - 2
#
# - Enter a letter grade A/a, B/b, C/c, D/d, and then displays its corresponding numeric value 90, 80, 70, 60.
#
# ## Sample Run
# ```
# Enter a letter grade: B
# The numeric value for grade B is 80
# ```
#
# ```python
# letter = input("Enter a letter grade: ")
#
# if letter in 'Aa':
#     print("The numeric value for grade A is 90")
# elif letter in 'Bb':
#     print("The numeric value for grade B is 80")
# elif letter in 'Cc':
#     print("The numeric value for grade C is 70")
# elif letter in 'Dd':
#     print("The numeric value for grade D is 60")
# else:
#     print(letter, "is an invalid grade")
# ```
#
# - Letter in “Aa”
# - Multiple way if statements
# ---
# # Individual Assignment 4 - 3
#
# - Display number of days in the month.
#
# ## Sample Run
# ```
# Enter a year: 2001
# Enter a month: Jan
# Jan 2001 has 31 days
# ```
#
# A year is a **leap** year if **either** of the following conditions is satisfied:
# - The year is multiple of 400.
#   - `(year % 400) == 0` (in python)
# - The year is multiple of 4 and not multiple of 100.
#   - `(year % 4) == 0 and (year % 100) != 0` (in python)
#
# ```python
# year = int(input("Enter a year: "))
# month = input("Enter a month (first three letters with the first letter in uppercase): ")
#
# if month == "Jan" or month == "Mar" or month == "May" \
# or month == "Jul" or month == "Aug" or month == "Oct" or month == "Dec":
#     print(month, year, "has 31 days")
# elif month == "Apr" or month == "Jun" or month == "Sep" or month == "Nov":
#     print(month, year, "has 30 days")
# elif month == "Feb":
#     if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
#         print(month, year, "has 29 days")
#     else:
#         print(month, year, "has 28 days")
# else:
#     print(month, "is not a correct month name")
# ```
# ---
# # Individual Assignment 5 - 1
#
# - Prompts the user to enter a string and displays its length and its first character.
#
# ## Sample Run
#
# ```
# Enter a string: Programming is fun
# The length of string "Programming is fun" is 18
# The last character of string Programming is fun is n
# ```
#
# ## Code
#
# ```python
# s = input("Enter a string: ")
#
# print("The length of string \"Programming is fun\" is ", len(s))
#
# print("The last character of string Programming is fun is ", s[-1])
# ```
# ---
# # Individual Assignment 5 - 2
#
# - **Decide major and year**
#   - M: Mathematics
#   - C: Computer Science
#   - I: Information Technology
#
# ## Sample Run
# ```
# Enter two characters: M1
# Mathematics
# Freshman
# ```
#
# ```python
# # More efficient with list created
# s = input("Enter two characters: ")
#
# ms = ['M', 'C', 'I']
# majors = ['Mathematics', 'Computer Science', 'Information Technology']
# years = ['Freshman', 'Sophomore', 'Junior', 'Senior']
#
# year = int(s[1])
# major = majors[ms.index(s[0])]
#
# print(major)
# print(years[year - 1])
# ```
# ---
# # Individual Assignment 5 - 3
#
# - **An ISBN-9 to ISBN-10 converter (without function)**
#
#   If the checksum is 10, the last digit is denoted as X according to the ISBN-10 convention.
#
#   ```
#   checksum = (d₁ * 1 + d₂ * 2 + d₃ * 3 + d₄ * 4 + d₅ * 5 + d₆ * 6 + d₇ * 7 + d₈ * 8 + d₉ * 9) % 11
#   ```
#
# ## Sample Run 1
# ```
# Enter the first 9 digits of an ISBN as a string: 3601267
# Incorrect input.
# -----
